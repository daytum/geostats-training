# %% [markdown]
# <div style="width: 800">
#   <div style="width: 400; float: left">
#     <a href='https://www.daytum.io/'><img src="https://github.com/daytum/logos/blob/master/daytum_logo_2019.png?raw=true" alt="Daytum" style="width: 250px;"/></a>
#     <br><br>
#   </div>
#   <div style="width: 100; float: left;">
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#   </div>
#   <div style="width: 900; float: right;">
#     <span title="LinkedIn"><a href='https://www.linkedin.com/company/daytum-io/?viewAsMember=true'><img src="https://github.com/daytum/logos/blob/master/linkedin.png?raw=true" width="40" height="40"></a></span>&emsp;<span title="Youtube"><a href='https://www.youtube.com/channel/UCzXrjXfB1eSUNuw1O_GtFyQ'><img src="https://github.com/daytum/logos/blob/master/youtube.png?raw=true" width="40" height="40"></a></span>&emsp;<span title="Slack community"><a href='https://join.slack.com/t/daytumcommunity/shared_invite/zt-9wek6952-mldfIMsY4YVN9uGh_huLWg'><img src="https://github.com/daytum/logos/blob/master/myspace.png?raw=true" width="40" height="40"></a></span>&emsp;<span title="Twitter"><a href='https://twitter.com/daytum_io?lang=en'><img src="https://github.com/daytum/logos/blob/master/twitter.png?raw=true" width="40" height="40"></a></span>&emsp;<span title="Email daytum"><a href='mailto: contact@daytum.io'><img src="https://github.com/daytum/logos/blob/master/telegram.png?raw=true" width="40" height="40"></a></span>&emsp;<span title="Instagram"><a href='https://www.instagram.com/daytum.io/'><img src="https://github.com/daytum/logos/blob/master/instagram.png?raw=true" width="40" height="40"></a></span>
#   </div>
# </div>

# %% [markdown]
# ---
# Welcome to the daytum Online Classroom!<br><br>Why Learn Energy Data Science?<br><br>
# These courses will help you better understand, analyze, and visualize your data.<br>
# Our courses apply Python for Data Science and Machine Learning with specific Subsurface examples.<br>
# You will find Python to be a very versatile language with many applications.</h4>
#
# **If you would like us to teach at your company or have questions, contact us [HERE](mailto:contact@daytum.io)!**
#
# daytum course<!-- Advanced Subsurface ML -->
# <div class="item3">
#   <div class="header2"><b>Advanced Subsurface Machine Learning</b></div>
#   <div style="width: 100%;">
#     <div class="textformat">
#       <div style="float: left; width: 100%; margin: 0px 10px -10px 10px">
#         <h4><b>To deep dive into the theory and practical application of game theory and advanced machine learning methods to the subsurface <br>as a means for improving data-driven decision making.</h4><br>
#       </div>
#       <div style="float: left; width: 25%;">
#         <h3>PREREQUISITES</h3>
#         <ol>
#           <li>daytum - Introduction to Python Course</li>
#           <li>daytum - Introduction to Subsurface Machine Learning Course</li>
#         </ol>
#       </div>
#       <div style="float: left; width: 25%;">
#         <h3>LECTURES</h3>
#         <ol>
#           <li><a href="AdvancedSubsurfaceMLNotes/01Introduction.pdf">Introduction</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/02BayesianProbability.pdf">Bayesian Probability</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/03MCS_bootstrap.pdf">MCS Bootstrap</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/04FeatureRanking.pdf">Feature Ranking</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/05MachineLearningRefresher.pdf">Machine Learning Refresher</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/06AdvancedClustering.pdf">Advanced Clustering<</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/07Uncertainty.pdf">Uncertainty</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/08DecisionMaking.pdf">Decision Making</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/09SpatialBootstrap.pdf">Spatial Bootstrap</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/10Shapley.pdf">Shapley</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/11GameTheoryNonCooperative.pdf">Game Theory Noncooperative</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/12TimeSeriesAnalysis.pdf">Time Series Analysis</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/13NeuralNetworks.pdf">Neural Networks</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/14ConvolutionalNeuralNetworks.pdf">Convolution Neural Networks</a></li>
#           <li><a href="AdvancedSubsurfaceMLNotes/15GenerativeAdversarialNetworks.pdf">Generative Adversarial Networks</a></li>
#         </ol>
#       </div>
#       <div style="float: left; width: 25%;">
#         <h3>VIDEOS</h3>
#         <ol>
#           COMING SOON!
#         </ol>
#       </div>
#       <div style="float: left; width: 25%;">
#         <h3>WORKFLOWS</h3>
#         <ol>
#           <li><a href="AdvancedSubsurfaceMLExercises/01InteractiveSiviaCoinToss.ipynb">Interactive Sivia Coin Toss</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/02BayesianRegression.ipynb">Bayesian Regression</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/03Bootstrap.ipynb">Bootstrap</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/04InteractiveBootstrapSimple.ipynb">Interactive Bootstrap Simple</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/05InteractiveMonteCarloSimulation.ipynb">Interactive Monte Carlo Sim</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/06FeatureRanking.ipynb">Feature Ranking</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/07AdvancedClustering.ipynb">Advanced Clustering</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/08InteractiveSpectralClustering.ipynb">Interactive Spectral Clustering</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/09InteractiveDecisionMaking.ipynb">Interactive Decision Making</a></li>
#           <li><a href="">Decision Making with Loss Function Demo</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/11SpatialBootstrap.ipynb">Spatial Bootstrap</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/12FeatureRanking.ipynb">Feature Ranking</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/13InteractiveShapley.ipynb">Interactive Shapley</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/14TimeSeriesAnalysis.ipynb">Time Series</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/15NeuralNet.ipynb">Neural Net</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/16ConvolutionalNeuralNetworksClassifierVerySimple.ipynb">CNN - Very Simple</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/17ConvolutionalNeuralNetworksClassifierLocationInvariance.ipynb">CNN - Local Invariance</a></li>
#           <li><a href="AdvancedSubsurfaceMLExercises/18ConvolutionalNeuralNetworksClassifierScale.ipynb">CNN - Scale</a></li>
#         </ol>
#       </div>
#     </div>
#   </div>
# </div>s have been taken by employees at:<br><br>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/86/Chevron_Logo.svg/918px-Chevron_Logo.svg.png" style="width: 40px;"/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/0/09/Oasis_petroleum_logo.svg/1200px-Oasis_petroleum_logo.svg.png" style="width: 60px;"/>
# &nbsp;&nbsp;&nbsp;&nbsp;
# <img src="https://china.aramco.com/-/media/aramcochina/news/logo01.jpg?w=1440&hash=3EBC01163D4F2674F66858B79B47498916E8F3F5" style="width: 90px;"/>
# &nbsp;&nbsp;&nbsp;&nbsp;
# <img src="https://www.equinor.com/content/dam/statoil/image/news/2018-march/equinor-logo-rgb-16-9.jpg" style="width: 100px;"/>
# &nbsp;&nbsp;&nbsp;&nbsp;
# <img src="https://1000logos.net/wp-content/uploads/2020/09/ConocoPhillips-Logo.png" style="width: 100px;"/>
# &nbsp;&nbsp;&nbsp;&nbsp;
# <img src="https://1000logos.net/wp-content/uploads/2016/10/BP-Logo.png" style="width: 100px;"/>
# &nbsp;&nbsp;&nbsp;&nbsp;
# <img src="https://static.mubasher.info/File.Story_Image/83d90a8e4803f336af4382b2a4bfef34/640.jpg" style="width: 90px;"/>
# &nbsp;&nbsp;&nbsp;&nbsp;
# <img src="https://www.logolynx.com/images/logolynx/b6/b6380ac30cd856fb39f9260d2ba1835a.gif" style="width: 40px;"/>
# <p><i>&copy; Copyright daytum 2021. All Rights Reserved</i></p>
